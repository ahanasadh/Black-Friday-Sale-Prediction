# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.drop(["User_ID","Product_ID"],axis=1,inplace=True)

# %%
df
# Out:
#        Gender    Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0           F   0-17          10             A                          2
# 1           F   0-17          10             A                          2
# 2           F   0-17          10             A                          2
# 3           F   0-17          10             A                          2
# 4           M    55+          16             C                         4+
# ...       ...    ...         ...           ...                        ...
# 550063      M  51-55          13             B                          1
# 550064      F  26-35           1             C                          3
# 550065      F  26-35          15             B                         4+
# 550066      F    55+           1             C                          2
# 550067      F  46-50           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df.Gender=df.Gender.apply(lambda x: 0 if x=="M" else 1)

# %%
df.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
def age(x):
    if len(x)==3:
        return int(x[:-1])
    tokens=x.split("-")
    return (int(tokens[0])+(int(tokens[1]))//2)

# %%
df.Age=df.Age.apply(age)

# %%
df
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            1    8          10             A                          2
# 1            1    8          10             A                          2
# 2            1    8          10             A                          2
# 3            1    8          10             A                          2
# 4            0   55          16             C                         4+
# ...        ...  ...         ...           ...                        ...
# 550063       0   78          13             B                          1
# 550064       1   43           1             C                          3
# 550065       1   43          15             B                         4+
# 550066       1   55           1             C                          2
# 550067       1   71           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
city=pd.get_dummies(df["City_Category"])
city
# Out:
#         A  B  C
# 0       1  0  0
# 1       1  0  0
# 2       1  0  0
# 3       1  0  0
# 4       0  0  1
# ...    .. .. ..
# 550063  0  1  0
# 550064  0  0  1
# 550065  0  1  0
# 550066  0  0  1
# 550067  0  1  0
#
# [550068 rows x 3 columns]

# %%
city.drop(["C"],axis=1,inplace=True)

# %%
df2=pd.concat([df,city])

# %%
df
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            1    8          10             A                          2
# 1            1    8          10             A                          2
# 2            1    8          10             A                          2
# 3            1    8          10             A                          2
# 4            0   55          16             C                         4+
# ...        ...  ...         ...           ...                        ...
# 550063       0   78          13             B                          1
# 550064       1   43           1             C                          3
# 550065       1   43          15             B                         4+
# 550066       1   55           1             C                          2
# 550067       1   71           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            1    8          10             A                          2
# 1            1    8          10             A                          2
# 2            1    8          10             A                          2
# 3            1    8          10             A                          2
# 4            0   55          16             C                         4+
# ...        ...  ...         ...           ...                        ...
# 550063       0   78          13             B                          1
# 550064       1   43           1             C                          3
# 550065       1   43          15             B                         4+
# 550066       1   55           1             C                          2
# 550067       1   71           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
city
# Out:
#         A  B
# 0       1  0
# 1       1  0
# 2       1  0
# 3       1  0
# 4       0  0
# ...    .. ..
# 550063  0  1
# 550064  0  0
# 550065  0  1
# 550066  0  0
# 550067  0  1
#
# [550068 rows x 2 columns]

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            1    8          10             A                          2
# 1            1    8          10             A                          2
# 2            1    8          10             A                          2
# 3            1    8          10             A                          2
# 4            0   55          16             C                         4+
# ...        ...  ...         ...           ...                        ...
# 550063       0   78          13             B                          1
# 550064       1   43           1             C                          3
# 550065       1   43          15             B                         4+
# 550066       1   55           1             C                          2
# 550067       1   71           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df2=pd.concat([df,city],axis=1)

# %%
df2
# Out:
#         Gender  Age  Occupation City_Category Stay_In_Current_City_Years  \
# 0            1    8          10             A                          2
# 1            1    8          10             A                          2
# 2            1    8          10             A                          2
# 3            1    8          10             A                          2
# 4            0   55          16             C                         4+
# ...        ...  ...         ...           ...                        ...
# 550063       0   78          13             B                          1
# 550064       1   43           1             C                          3
# 550065       1   43          15             B                         4+
# 550066       1   55           1             C                          2
# 550067       1   71           0             B                         4+
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
df2.drop(["City_Category"],axis=1,inplace=True)

# %%
df2
# Out:
#         Gender  Age  Occupation Stay_In_Current_City_Years  Marital_Status  \
# 0            1    8          10                          2               0
# 1            1    8          10                          2               0
# 2            1    8          10                          2               0
# 3            1    8          10                          2               0
# 4            0   55          16                         4+               0
# ...        ...  ...         ...                        ...             ...
# 550063       0   78          13                          1               1
# 550064       1   43           1                          3               0
# 550065       1   43          15                         4+               1
# 550066       1   55           1                          2               0
# 550067       1   71           0                         4+               1
#
# ...

# %%
df2.Stay_In_Current_City_Years.unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df2["Stay"]=df2.Stay_In_Current_City_Years.apply(lambda x: int(x[0]))

# %%
df2.drop(["Stay_In_Current_City_Years"],axis=1,inplace=True)

# %%
df2.A = df2.A.apply(lambda x: int(x))
df2.B = df2.B.apply(lambda x: int(x))
df2.dtypes
# Out:
# Gender                  int64
# Age                     int64
# Occupation              int64
# Marital_Status          int64
# Product_Category_1      int64
# Product_Category_2    float64
# Product_Category_3    float64
# Purchase                int64
# A                       int64
# B                       int64
# Stay                    int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(df2.drop(["Purchase"],axis=1), df2.Purchase, test_size = 0.3)

# %%
xtest
# Out:
#         Gender  Age  Occupation  Marital_Status  Product_Category_1  \
# 360221       0   43           1               1                   8
# 363412       1   58           7               0                   1
# 96394        0   30           4               0                   1
# 448906       0   43          14               0                   5
# 36472        1   30           4               0                   5
# ...        ...  ...         ...             ...                 ...
# 408687       0   43           2               1                   1
# 90108        0   58          12               0                  16
# 22129        1   71           7               1                  16
# 345270       0   43          12               0                   8
# 126152       1   43           3               0                   1
#
#         Product_Category_2  Product_Category_3  A  B  Stay
# 360221                16.0                 0.0  0  1     1
# ...

# %%
from sklearn.ensemble import RandomForestRegressor,HistGradientBoostingRegressor,AdaBoostRegressor

# %%
model = HistGradientBoostingRegressor()

# %%
model.fit(xtrain, ytrain)
# Out:
# HistGradientBoostingRegressor()

# %%
df2
# Out:
#         Gender  Age  Occupation  Marital_Status  Product_Category_1  \
# 0            1    8          10               0                   3
# 1            1    8          10               0                   1
# 2            1    8          10               0                  12
# 3            1    8          10               0                  12
# 4            0   55          16               0                   8
# ...        ...  ...         ...             ...                 ...
# 550063       0   78          13               1                  20
# 550064       1   43           1               0                  20
# 550065       1   43          15               1                  20
# 550066       1   55           1               0                  20
# 550067       1   71           0               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase  A  B  Stay
# 0                      0.0                 0.0      8370  1  0     2
# ...

# %%
model.score(xtest,ytest)
# Out:
# 0.6661803189636762

# %%
import pickle

# %%
with open("HistGradientBoostingRegressorModel.pkl","wb") as f:
    pickle.dump(model,f)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x = scaler.fit_transform(df2.drop(["Purchase"], axis = 1))

# %%
x.shape
# Out:
# (550068, 10)

# %%
y = scaler.fit_transform([df2.Purchase])

# %%
y[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
y.shape
# Out:
# (1, 550068)

# %%
import tensorflow.keras as tf

# %%
model = tf.models.Sequential([
    tf.layers.Dense(5,input_shape=(10,1),activation="relu"),
    tf.layers.Dense(9,activation="relu"),
    tf.layers.Dense(1,activation="relu")
])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y[0],test_size=0.3)
model.compile(loss=tf.losses.mean_absolute_percentage_error,optimizer="adam",metrics=["accuracy"])

# %%
model.fit(x_train,y_train,epochs=1,)
# Out:
# 12033/12033 [==============================] - 55s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000

# %%
model.evaluate(x_test,y_test)
# Out:
# 5157/5157 [==============================] - 19s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# [0.0, 1.0]

# %%
with open("ANN.pickle","wb") as f:
    pickle.dump(model,f)
